# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

file_path = "data/STFMK-20201105-LW15-2055_20201125_163909_004.csv"
df_motor = pd.read_csv(file_path, encoding="cp949")

# %%
df = df_motor.loc[:'2000']

# %%
df_motor.head()
# Out:
#          x         y
# 0  0.00000  0.003176
# 1  0.00025  0.002670
# 2  0.00050  0.002354
# 3  0.00075  0.002277
# 4  0.00100  0.000140

# %%
px.line(data_frame=df, x = df.index, y = 'x')

# %%
px.line(data_frame=df, x = df.index, y = 'y')

# %%
px.line(data_frame=df, x=df.index, y='y', color='x')

# %%
import librosa
import librosa.display
import torch
import torchaudio
import IPython.display as ipd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 import librosa
#       2 import librosa.display
#       3 import torch
#
# ModuleNotFoundError: No module named 'librosa'
