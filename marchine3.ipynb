# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCaveOfAdullam/study1/blob/main/marchine3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-model-optimization

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow_model_optimization.sparsity import keras as sparsity
# Out:
# Requirement already satisfied: tensorflow-model-optimization in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization) (1.25.2)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization) (1.16.0)

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
# loading img
import PIL.Image as Image

p = '/content/drive/MyDrive/deajeon_motor'
os.chdir(p)

# Resize image function
def resize_img(img, size):
    return img.resize(size)

def load_img(file_path):
    data = []
    for f in os.listdir(file_path):
        img = Image.open(p + file_path[1:] + '/' + f).convert('RGB')
        data.append(resize_img(img, (64, 64)))
    return data

# Convert images to arrays
def img_to_array(img):
    return np.array(img, dtype='float32') / 255.0

# %%
# Define paths and load data
train_normal = load_img('./train/normal')
test_normal = load_img('./test/normal')
val_normal = load_img('./validation/normal')

train_fault = load_img('./train/fault')
test_fault = load_img('./test/fault')
val_fault = load_img('./validation/fault')

# %%
len(train_normal), len(test_normal), len(val_normal), len(train_fault), len(test_fault), len(val_fault)
# Out:
# (3000, 3000, 1500, 3000, 3000, 1500)

# %%
def img_to_array(img):
    return np.array(img, dtype='float32') / 255.0

train_normal_arr, train_normal_sol = np.array([img_to_array(normal) for normal in train_normal]), np.array([1] * len(train_normal))
test_normal_arr, test_normal_sol = np.array([img_to_array(normal) for normal in test_normal]), np.array([1] * len(test_normal))
val_normal_arr, val_normal_sol = np.array([img_to_array(normal) for normal in val_normal]), np.array([1] * len(val_normal))

train_fault_arr, train_fault_sol = np.array([img_to_array(fault) for fault in train_fault]), np.array([0] * len(train_fault))
test_fault_arr, test_fault_sol = np.array([img_to_array(fault) for fault in test_fault]), np.array([0] * len(test_fault))
val_fault_arr, val_fault_sol = np.array([img_to_array(fault) for fault in val_fault]), np.array([0] * len(val_fault))

# Combine normal and fault data
train_img, train_sol = np.concatenate((train_normal_arr, train_fault_arr)), np.concatenate((train_normal_sol, train_fault_sol))
test_img, test_sol = np.concatenate((test_normal_arr, test_fault_arr)), np.concatenate((test_normal_sol, test_fault_sol))
val_img, val_sol = np.concatenate((val_normal_arr, val_fault_arr)), np.concatenate((val_normal_sol, val_fault_sol))

# %%
# Define the CNN model
def create_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

# Compile the model
model = create_model()
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_img, train_sol, epochs=50, validation_data=(val_img, val_sol))

# Evaluate the model on the test data
original_score = model.evaluate(test_img, test_sol)
print(f'Original model test loss: {original_score[0]}, test accuracy: {original_score[1]}')
# Out:
# Epoch 1/50
# 188/188 [==============================] - 64s 324ms/step - loss: 0.3126 - accuracy: 0.8292 - val_loss: 0.0148 - val_accuracy: 0.9987
# Epoch 2/50
# 188/188 [==============================] - 44s 236ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 0.0053 - val_accuracy: 0.9997
# Epoch 3/50
# 188/188 [==============================] - 49s 259ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0500 - val_accuracy: 0.9823
# Epoch 4/50
# 188/188 [==============================] - 46s 247ms/step - loss: 0.0129 - accuracy: 0.9953 - val_loss: 0.0186 - val_accuracy: 0.9933
# Epoch 5/50
# 188/188 [==============================] - 44s 236ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0098 - val_accuracy: 0.9960
# Epoch 6/50
# 188/188 [==============================] - 45s 241ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0036 - val_accuracy: 0.9990
# Epoch 7/50
# 188/188 [==============================] - 44s 234ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9963
# Epoch 8/50
# 188/188 [==============================] - 45s 239ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0059 - val_accuracy: 0.9983
# Epoch 9/50
# 188/188 [==============================] - 44s 233ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0040 - val_accuracy: 0.9987
# Epoch 10/50
# 188/188 [==============================] - 44s 235ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0500 - val_accuracy: 0.9800
# Epoch 11/50
# 188/188 [==============================] - 47s 249ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0140 - val_accuracy: 0.9940
# Epoch 12/50
# 188/188 [==============================] - 44s 237ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0034 - val_accuracy: 0.9983
# Epoch 13/50
# 188/188 [==============================] - 43s 231ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0309 - val_accuracy: 0.9893
# Epoch 14/50
# 188/188 [==============================] - 44s 233ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0554 - val_accuracy: 0.9813
# Epoch 15/50
# 188/188 [==============================] - 48s 256ms/step - loss: 1.1364e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9860
# Epoch 16/50
# 188/188 [==============================] - 45s 238ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0087 - val_accuracy: 0.9970
# Epoch 17/50
# 188/188 [==============================] - 50s 266ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0791 - val_accuracy: 0.9720
# Epoch 18/50
# 188/188 [==============================] - 51s 272ms/step - loss: 3.1167e-04 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9793
# Epoch 19/50
# 188/188 [==============================] - 43s 231ms/step - loss: 1.9736e-04 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9947
# Epoch 20/50
# 188/188 [==============================] - 43s 231ms/step - loss: 5.8591e-05 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9840
# Epoch 21/50
# 188/188 [==============================] - 43s 231ms/step - loss: 3.6855e-05 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9803
# Epoch 22/50
# 188/188 [==============================] - 47s 252ms/step - loss: 2.6983e-05 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9920
# Epoch 23/50
# 188/188 [==============================] - 43s 231ms/step - loss: 3.3861e-05 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9883
# Epoch 24/50
# 188/188 [==============================] - 43s 231ms/step - loss: 4.1778e-05 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9907
# Epoch 25/50
# 188/188 [==============================] - 44s 235ms/step - loss: 1.1198e-05 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9907
# Epoch 26/50
# 188/188 [==============================] - 43s 226ms/step - loss: 1.8964e-04 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9877
# Epoch 27/50
# 188/188 [==============================] - 42s 224ms/step - loss: 2.0572e-05 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9867
# Epoch 28/50
# 188/188 [==============================] - 44s 236ms/step - loss: 1.9433e-05 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9790
# Epoch 29/50
# 188/188 [==============================] - 44s 236ms/step - loss: 3.8654e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9910
# Epoch 30/50
# 188/188 [==============================] - 48s 255ms/step - loss: 4.2859e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9973
# Epoch 31/50
# 188/188 [==============================] - 43s 231ms/step - loss: 0.0400 - accuracy: 0.9932 - val_loss: 1.3412 - val_accuracy: 0.7210
# Epoch 32/50
# 188/188 [==============================] - 44s 234ms/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.2781 - val_accuracy: 0.9093
# Epoch 33/50
# 188/188 [==============================] - 43s 229ms/step - loss: 4.4709e-04 - accuracy: 0.9998 - val_loss: 0.1969 - val_accuracy: 0.9343
# Epoch 34/50
# 188/188 [==============================] - 48s 253ms/step - loss: 5.5388e-04 - accuracy: 0.9997 - val_loss: 0.1505 - val_accuracy: 0.9513
# Epoch 35/50
# 188/188 [==============================] - 43s 229ms/step - loss: 1.7047e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9613
# Epoch 36/50
# 188/188 [==============================] - 43s 228ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 0.0557 - val_accuracy: 0.9817
# Epoch 37/50
# 188/188 [==============================] - 43s 228ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.3869 - val_accuracy: 0.8947
# Epoch 38/50
# 188/188 [==============================] - 41s 219ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.2338 - val_accuracy: 0.9180
# Epoch 39/50
# 188/188 [==============================] - 43s 227ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.2798 - val_accuracy: 0.9087
# Epoch 40/50
# 188/188 [==============================] - 44s 233ms/step - loss: 2.5572e-04 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9557
# Epoch 41/50
# 188/188 [==============================] - 44s 232ms/step - loss: 1.8948e-04 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9453
# Epoch 42/50
# 188/188 [==============================] - 43s 227ms/step - loss: 1.2381e-04 - accuracy: 1.0000 - val_loss: 0.4206 - val_accuracy: 0.8890
# Epoch 43/50
# 188/188 [==============================] - 47s 250ms/step - loss: 9.8081e-05 - accuracy: 1.0000 - val_loss: 0.3885 - val_accuracy: 0.8997
# Epoch 44/50
# 188/188 [==============================] - 45s 239ms/step - loss: 9.2556e-04 - accuracy: 0.9997 - val_loss: 0.1029 - val_accuracy: 0.9713
# Epoch 45/50
# 188/188 [==============================] - 48s 255ms/step - loss: 1.2518e-04 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9663
# Epoch 46/50
# 188/188 [==============================] - 46s 247ms/step - loss: 7.9055e-05 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9397
# Epoch 47/50
# 188/188 [==============================] - 43s 228ms/step - loss: 2.8985e-05 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9643
# Epoch 48/50
# 188/188 [==============================] - 43s 232ms/step - loss: 1.8839e-05 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9633
# Epoch 49/50
# 188/188 [==============================] - 47s 251ms/step - loss: 8.0850e-05 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9500
# Epoch 50/50
# 188/188 [==============================] - 44s 235ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1931 - val_accuracy: 0.9307
# 188/188 [==============================] - 12s 64ms/step - loss: 0.0996 - accuracy: 0.9690
# Original model test loss: 0.09959007799625397, test accuracy: 0.968999981880188

# %%
# Prune the model
batch_size = 32
epochs = 50
validation_split = 0.1

num_images = train_img.shape[0] * (1 - validation_split)
end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs

pruning_params = {
    'pruning_schedule': sparsity.PolynomialDecay(initial_sparsity=0.50,
                                                 final_sparsity=0.90,
                                                 begin_step=0,
                                                 end_step=end_step)
}

pruned_model = sparsity.prune_low_magnitude(create_model(), **pruning_params)

# Compile the pruned model
pruned_model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the pruned model
callbacks = [sparsity.UpdatePruningStep()]

pruned_history = pruned_model.fit(train_img, train_sol, epochs=epochs, batch_size=batch_size,
                                  validation_split=validation_split, callbacks=callbacks)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 44s 229ms/step - loss: 0.3056 - accuracy: 0.8480 - val_loss: 0.0302 - val_accuracy: 0.9917
# Epoch 2/50
# 169/169 [==============================] - 37s 217ms/step - loss: 0.0289 - accuracy: 0.9906 - val_loss: 0.0319 - val_accuracy: 0.9867
# Epoch 3/50
# 169/169 [==============================] - 38s 227ms/step - loss: 0.0083 - accuracy: 0.9993 - val_loss: 0.0331 - val_accuracy: 0.9883
# Epoch 4/50
# 169/169 [==============================] - 36s 212ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.0197 - val_accuracy: 0.9883
# Epoch 5/50
# 169/169 [==============================] - 38s 226ms/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 0.0680 - val_accuracy: 0.9800
# Epoch 6/50
# 169/169 [==============================] - 36s 214ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0183 - val_accuracy: 0.9900
# Epoch 7/50
# 169/169 [==============================] - 43s 252ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0255 - val_accuracy: 0.9900
# Epoch 8/50
# 169/169 [==============================] - 36s 215ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.1902 - val_accuracy: 0.9367
# Epoch 9/50
# 169/169 [==============================] - 43s 254ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.2833 - val_accuracy: 0.9183
# Epoch 10/50
# 169/169 [==============================] - 35s 209ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0596 - val_accuracy: 0.9817
# Epoch 11/50
# 169/169 [==============================] - 36s 214ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0296 - val_accuracy: 0.9900
# Epoch 12/50
# 169/169 [==============================] - 38s 224ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.1148 - val_accuracy: 0.9667
# Epoch 13/50
# 169/169 [==============================] - 35s 208ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 5.5687e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 169/169 [==============================] - 37s 222ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.0263 - val_accuracy: 0.9900
# Epoch 15/50
# 169/169 [==============================] - 37s 220ms/step - loss: 0.0100 - accuracy: 0.9980 - val_loss: 0.1019 - val_accuracy: 0.9717
# Epoch 16/50
# 169/169 [==============================] - 38s 228ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0402 - val_accuracy: 0.9867
# Epoch 17/50
# 169/169 [==============================] - 36s 211ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.0549 - val_accuracy: 0.9867
# Epoch 18/50
# 169/169 [==============================] - 38s 224ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1416 - val_accuracy: 0.9650
# Epoch 19/50
# 169/169 [==============================] - 36s 211ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0715 - val_accuracy: 0.9783
# Epoch 20/50
# 169/169 [==============================] - 37s 219ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0375 - val_accuracy: 0.9883
# Epoch 21/50
# 169/169 [==============================] - 39s 230ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0467 - val_accuracy: 0.9883
# Epoch 22/50
# 169/169 [==============================] - 36s 210ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 1.2523e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 169/169 [==============================] - 37s 220ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.1265 - val_accuracy: 0.9717
# Epoch 24/50
# 169/169 [==============================] - 35s 210ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0321 - val_accuracy: 0.9917
# Epoch 25/50
# 169/169 [==============================] - 38s 223ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0571 - val_accuracy: 0.9883
# Epoch 26/50
# 169/169 [==============================] - 36s 212ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0146 - val_accuracy: 0.9933
# Epoch 27/50
# 169/169 [==============================] - 37s 217ms/step - loss: 0.0029 - accuracy: 0.9985 - val_loss: 0.0923 - val_accuracy: 0.9833
# Epoch 28/50
# 169/169 [==============================] - 36s 211ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0739 - val_accuracy: 0.9867
# Epoch 29/50
# 169/169 [==============================] - 35s 208ms/step - loss: 0.0032 - accuracy: 0.9980 - val_loss: 0.1966 - val_accuracy: 0.9533
# Epoch 30/50
# 169/169 [==============================] - 37s 222ms/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.1544 - val_accuracy: 0.9667
# Epoch 31/50
# 169/169 [==============================] - 35s 208ms/step - loss: 0.0024 - accuracy: 0.9983 - val_loss: 0.0570 - val_accuracy: 0.9900
# Epoch 32/50
# 169/169 [==============================] - 37s 221ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0065 - val_accuracy: 0.9967
# Epoch 33/50
# 169/169 [==============================] - 36s 211ms/step - loss: 0.0095 - accuracy: 0.9959 - val_loss: 0.0530 - val_accuracy: 0.9900
# Epoch 34/50
# 169/169 [==============================] - 36s 212ms/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.0356 - val_accuracy: 0.9917
# Epoch 35/50
# 169/169 [==============================] - 37s 217ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.0552 - val_accuracy: 0.9883
# Epoch 36/50
# 169/169 [==============================] - 35s 209ms/step - loss: 0.0051 - accuracy: 0.9976 - val_loss: 0.0713 - val_accuracy: 0.9883
# Epoch 37/50
# 169/169 [==============================] - 37s 219ms/step - loss: 0.0050 - accuracy: 0.9970 - val_loss: 0.0377 - val_accuracy: 0.9933
# Epoch 38/50
# 169/169 [==============================] - 35s 209ms/step - loss: 0.0055 - accuracy: 0.9957 - val_loss: 0.0601 - val_accuracy: 0.9900
# Epoch 39/50
# 169/169 [==============================] - 37s 219ms/step - loss: 0.0076 - accuracy: 0.9959 - val_loss: 0.0553 - val_accuracy: 0.9883
# Epoch 40/50
# 169/169 [==============================] - 35s 209ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0347 - val_accuracy: 0.9933
# Epoch 41/50
# 169/169 [==============================] - 36s 213ms/step - loss: 0.0126 - accuracy: 0.9944 - val_loss: 0.0300 - val_accuracy: 0.9917
# Epoch 42/50
# 169/169 [==============================] - 37s 218ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0899 - val_accuracy: 0.9833
# Epoch 43/50
# 169/169 [==============================] - 35s 210ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0734 - val_accuracy: 0.9867
# Epoch 44/50
# 169/169 [==============================] - 38s 222ms/step - loss: 0.0104 - accuracy: 0.9956 - val_loss: 1.0221 - val_accuracy: 0.7950
# Epoch 45/50
# 169/169 [==============================] - 35s 205ms/step - loss: 0.0125 - accuracy: 0.9946 - val_loss: 0.0628 - val_accuracy: 0.9883
# Epoch 46/50
# 169/169 [==============================] - 36s 215ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0587 - val_accuracy: 0.9900
# Epoch 47/50
# 169/169 [==============================] - 34s 203ms/step - loss: 0.0081 - accuracy: 0.9963 - val_loss: 0.0824 - val_accuracy: 0.9883
# Epoch 48/50
# 169/169 [==============================] - 35s 210ms/step - loss: 0.0105 - accuracy: 0.9946 - val_loss: 0.0121 - val_accuracy: 0.9933
# Epoch 49/50
# 169/169 [==============================] - 36s 215ms/step - loss: 0.0082 - accuracy: 0.9961 - val_loss: 0.0575 - val_accuracy: 0.9917
# Epoch 50/50
# 169/169 [==============================] - 35s 207ms/step - loss: 0.0084 - accuracy: 0.9959 - val_loss: 0.0601 - val_accuracy: 0.9917

# %%
import tensorflow_model_optimization as tfmot

# Strip pruning wrappers
final_pruned_model = tfmot.sparsity.keras.strip_pruning(pruned_model)

# Save the original and pruned models
model.save('original_model.keras')
final_pruned_model.save('pruned_model_final.keras')

# %%
# Evaluate the pruned model on the test data
pruned_score = pruned_model.evaluate(test_img, test_sol)
print(f'Pruned model test loss: {pruned_score[0]}, test accuracy: {pruned_score[1]}')
# Out:
# 188/188 [==============================] - 11s 61ms/step - loss: 0.0409 - accuracy: 0.9912
# Pruned model test loss: 0.04093381389975548, test accuracy: 0.9911666512489319

# %%
# Save the original and pruned models in Keras format
model.save('original_model.keras')
final_pruned_model.save('pruned_model_final.keras')

# Get the file sizes
original_model_size = os.path.getsize('original_model.keras')
pruned_model_size = os.path.getsize('pruned_model_final.keras')

print(f'Original model size: {original_model_size / 1024:.2f} KB')
print(f'Pruned model size: {pruned_model_size / 1024:.2f} KB')
# Out:
# Original model size: 8053.44 KB
# Pruned model size: 2699.36 KB

# %%
# Plot the training and validation accuracy and loss
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Original Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Original Validation Accuracy')
plt.plot(pruned_history.history['accuracy'], label='Pruned Training Accuracy')
plt.plot(pruned_history.history['val_accuracy'], label='Pruned Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Original Training Loss')
plt.plot(history.history['val_loss'], label='Original Validation Loss')
plt.plot(pruned_history.history['loss'], label='Pruned Training Loss')
plt.plot(pruned_history.history['val_loss'], label='Pruned Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##5.3 혼동 행렬 및 분류 보고서
#
#
# 모델의 예측 성능을 더 세부적으로 평가하기 위해 혼동 행렬과 분류 보고서를 작성하였습니다.

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = (model.predict(test_img) > 0.5).astype(int).reshape(-1)
conf_matrix = confusion_matrix(test_sol, y_pred)
class_report = classification_report(test_sol, y_pred)
print("Confusion Matrix for Original Model:")
print(conf_matrix)
print("Classification Report for Original Model:")
print(class_report)

y_pred_pruned = (pruned_model.predict(test_img) > 0.5).astype(int).reshape(-1)
conf_matrix_pruned = confusion_matrix(test_sol, y_pred_pruned)
class_report_pruned = classification_report(test_sol, y_pred_pruned)
print("Confusion Matrix for Pruned Model:")
print(conf_matrix_pruned)
print("Classification Report for Pruned Model:")
print(class_report_pruned)
# Out:
# 188/188 [==============================] - 9s 47ms/step
# Confusion Matrix for Original Model:
# [[3000    0]
#  [ 186 2814]]
# Classification Report for Original Model:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      3000
#            1       1.00      0.94      0.97      3000
#
#     accuracy                           0.97      6000
#    macro avg       0.97      0.97      0.97      6000
# weighted avg       0.97      0.97      0.97      6000
#
# 188/188 [==============================] - 11s 56ms/step
# Confusion Matrix for Pruned Model:
# [[3000    0]
#  [  53 2947]]
# Classification Report for Pruned Model:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3000
#            1       1.00      0.98      0.99      3000
#
#     accuracy                           0.99      6000
#    macro avg       0.99      0.99      0.99      6000
# weighted avg       0.99      0.99      0.99      6000

# %% [markdown]
# ##5.4 ROC-AUC 곡선
#
# 모델의 분류 성능을 평가하기 위해 ROC-AUC 곡선을 작성하였습니다.

# %%
from sklearn.metrics import roc_curve, auc

y_pred_prob = model.predict(test_img).ravel()
fpr, tpr, thresholds = roc_curve(test_sol, y_pred_prob)
roc_auc = auc(fpr, tpr)

y_pred_prob_pruned = pruned_model.predict(test_img).ravel()
fpr_pruned, tpr_pruned, thresholds_pruned = roc_curve(test_sol, y_pred_prob_pruned)
roc_auc_pruned = auc(fpr_pruned, tpr_pruned)

plt.figure(figsize=(12, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='Original Model ROC curve (area = %0.2f)' % roc_auc)
plt.plot(fpr_pruned, tpr_pruned, color='darkorange', lw=2, label='Pruned Model ROC curve (area = %0.2f)' % roc_auc_pruned)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 188/188 [==============================] - 12s 65ms/step
# 188/188 [==============================] - 11s 58ms/step

# %% [markdown]
# ##5.5 F1-Score
#
# 모델의 정밀도와 재현율의 조화평균인 F1-Score를 계산하여 비교하였습니다.

# %%
from sklearn.metrics import f1_score

f1 = f1_score(test_sol, y_pred)
print(f"F1-score for Original Model: {f1}")

f1_pruned = f1_score(test_sol, y_pred_pruned)
print(f"F1-score for Pruned Model: {f1_pruned}")
# Out:
# F1-score for Original Model: 0.9680082559339525
# F1-score for Pruned Model: 0.9910879435009248

# %% [markdown]
# ##5.6 추론 시간
#
# 원래 모델과 가지치기된 모델의 추론 시간을 측정하였습니다.

# %%
import time

start_time = time.time()
model.predict(test_img)
end_time = time.time()
original_inference_time = end_time - start_time
print(f"Original Model Inference Time: {original_inference_time} seconds")

start_time = time.time()
pruned_model.predict(test_img)
end_time = time.time()
pruned_inference_time = end_time - start_time
print(f"Pruned Model Inference Time: {pruned_inference_time} seconds")
# Out:
# 188/188 [==============================] - 12s 62ms/step
# Original Model Inference Time: 21.337416887283325 seconds
# 188/188 [==============================] - 11s 60ms/step
# Pruned Model Inference Time: 12.90168833732605 seconds

# %% [markdown]
# 5.7 메모리 사용량
#
# 원래 모델과 가지치기된 모델의 메모리 사용량을 측정하였습니다.

# %%
import tracemalloc

tracemalloc.start()
model.predict(test_img)
current, peak = tracemalloc.get_traced_memory()
print(f"Original Model Memory Usage: Current={current / 10**6:.2f}MB; Peak={peak / 10**6:.2f}MB")
tracemalloc.stop()

tracemalloc.start()
pruned_model.predict(test_img)
current, peak = tracemalloc.get_traced_memory()
print(f"Pruned Model Memory Usage: Current={current / 10**6:.2f}MB; Peak={peak / 10**6:.2f}MB")
tracemalloc.stop()
# Out:
# 188/188 [==============================] - 13s 72ms/step
# Original Model Memory Usage: Current=0.23MB; Peak=295.05MB
# 188/188 [==============================] - 13s 67ms/step
# Pruned Model Memory Usage: Current=0.26MB; Peak=295.05MB
