# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score

import seaborn as sns
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data_time = pd.read_csv("archive/feature_time_48k_2048_load_1.csv")
data_time
# Out:
#           max      min      mean        sd       rms  skewness  kurtosis  \
# 0     0.35986 -0.41890  0.017840  0.122746  0.124006 -0.118571 -0.042219
# 1     0.46772 -0.36111  0.022255  0.132488  0.134312  0.174699 -0.081548
# 2     0.46855 -0.43809  0.020470  0.149651  0.151008  0.040339 -0.274069
# 3     0.58475 -0.54303  0.020960  0.157067  0.158422 -0.023266  0.134692
# 4     0.44685 -0.57891  0.022167  0.138189  0.139922 -0.081534  0.402783
# ...       ...      ...       ...       ...       ...       ...       ...
# 2295  0.21425 -0.19839  0.010769  0.064100  0.064983 -0.212497 -0.119312
# 2296  0.21967 -0.20882  0.013136  0.068654  0.069883 -0.061308 -0.295122
# 2297  0.20799 -0.21613  0.012571  0.067128  0.068279 -0.154754 -0.071405
# 2298  0.21425 -0.22405  0.012608  0.066813  0.067977 -0.326966  0.023662
# 2299  0.19610 -0.24721  0.012209  0.063243  0.064396 -0.351762  0.226294
#
#          crest      form       fault
# 0     2.901946  6.950855  Ball_007_1
# 1     3.482334  6.035202  Ball_007_1
# 2     3.102819  7.376926  Ball_007_1
# 3     3.691097  7.558387  Ball_007_1
# 4     3.193561  6.312085  Ball_007_1
# ...        ...       ...         ...
# 2295  3.297037  6.034174    Normal_1
# 2296  3.143410  5.319958    Normal_1
# 2297  3.046161  5.431299    Normal_1
# 2298  3.151821  5.391672    Normal_1
# 2299  3.045244  5.274392    Normal_1
#
# [2300 rows x 10 columns]

# %%
train_data, test_data = train_test_split(data_time, test_size = 750, stratify = data_time['fault'], random_state = 1234)
test_data['fault'].value_counts()
# Out:
# fault
# OR_007_6_1    75
# IR_014_1      75
# OR_014_6_1    75
# OR_021_6_1    75
# Normal_1      75
# IR_021_1      75
# Ball_014_1    75
# Ball_007_1    75
# Ball_021_1    75
# IR_007_1      75
# Name: count, dtype: int64

# %%
# Scale each column to have zero mean and standard deviation equal to 1
scaler = StandardScaler()
train_data_scaled = scaler.fit_transform(train_data.iloc[:,:-1])
pd.DataFrame(train_data_scaled).describe()
# Out:
#                   0             1             2             3             4  \
# count  1.550000e+03  1.550000e+03  1.550000e+03  1.550000e+03  1.550000e+03
# mean   1.260640e-16  1.002782e-16 -2.888012e-16  6.016693e-17 -5.386372e-17
# std    1.000323e+00  1.000323e+00  1.000323e+00  1.000323e+00  1.000323e+00
# min   -8.877055e-01 -2.951564e+00 -1.935376e+00 -9.258092e-01 -9.231913e-01
# 25%   -7.088474e-01 -3.753614e-01 -6.908705e-01 -6.755048e-01 -6.760659e-01
# 50%   -4.958143e-01  5.113022e-01 -3.141526e-01 -5.055027e-01 -5.038108e-01
# 75%    4.477234e-01  7.003484e-01  4.560105e-01  7.015641e-01  7.003255e-01
# max    3.297226e+00  8.671141e-01  3.503861e+00  2.980548e+00  2.981995e+00
#
#                   5             6             7             8
# count  1.550000e+03  1.550000e+03  1.550000e+03  1.550000e+03
# mean   1.833659e-17 -5.500976e-17  4.950878e-16 -2.521281e-17
# std    1.000323e+00  1.000323e+00  1.000323e+00  1.000323e+00
# min   -5.951422e+00 -7.874742e-01 -1.481163e+00 -7.775653e-01
# 25%   -3.678525e-01 -6.073122e-01 -8.064817e-01 -6.475107e-01
# 50%    2.140248e-01 -4.182916e-01 -2.135605e-01 -4.548003e-01
# 75%    5.823124e-01  2.860828e-01  5.648177e-01  4.360429e-01
# max    4.906756e+00  6.349353e+00  4.049712e+00  9.629399e+00

# %%
test_data_scaled = (test_data.iloc[:,:-1].values - scaler.mean_)/np.sqrt(scaler.var_)
pd.DataFrame(test_data_scaled).describe()
# Out:
#                 0           1           2           3           4           5  \
# count  750.000000  750.000000  750.000000  750.000000  750.000000  750.000000
# mean    -0.013718    0.003277   -0.018151   -0.013327   -0.013375   -0.035946
# std      0.976752    0.993896    1.003708    0.987301    0.987315    1.105931
# min     -0.895968   -2.754539   -1.590184   -0.922087   -0.922953   -6.014935
# 25%     -0.706453   -0.429163   -0.720867   -0.677965   -0.678545   -0.355683
# 50%     -0.494044    0.503185   -0.303458   -0.492809   -0.490457    0.224657
# 75%      0.394936    0.704214    0.401811    0.669274    0.667916    0.576534
# max      3.008545    0.861398    3.003970    2.885914    2.887282    6.301407
#
#                 6           7           8
# count  750.000000  750.000000  750.000000
# mean     0.018838    0.009379   -0.012433
# std      1.028360    0.998996    0.936491
# min     -0.759377   -1.515700   -0.772309
# 25%     -0.606352   -0.762882   -0.641796
# 50%     -0.415267   -0.219297   -0.452940
# 75%      0.294171    0.547845    0.447909
# max      5.007205    3.784107    3.531440

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()
svc_model.fit(train_data_scaled, train_data['fault'])
# Out:
# SVC()

# %%
train_predictions = svc_model.predict(train_data_scaled)
test_predictions = svc_model.predict(test_data_scaled)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
train_confu_matrix = confusion_matrix(train_data['fault'], train_predictions)
test_confu_matrix = confusion_matrix(test_data['fault'], test_predictions)

# %%
fault_type = data_time.fault.unique()

plt.figure(1,figsize=(18,8))

plt.subplot(121)
sns.heatmap(train_confu_matrix, annot= True,fmt = "d",
xticklabels=fault_type, yticklabels=fault_type, cmap = "Blues", cbar = False)
plt.title('Training Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.subplot(122)

plt.subplot(122)
sns.heatmap(test_confu_matrix, annot = True,
xticklabels=fault_type, yticklabels=fault_type, cmap = "Blues", cbar = False)
plt.title('Test Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

plt.show()

# %%
# Classification report (test set)
class_report = classification_report(y_pred = test_predictions, y_true = test_data['fault'])
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#   Ball_007_1       0.92      0.97      0.95        75
#   Ball_014_1       0.86      0.72      0.78        75
#   Ball_021_1       0.95      0.81      0.88        75
#     IR_007_1       0.99      1.00      0.99        75
#     IR_014_1       1.00      1.00      1.00        75
#     IR_021_1       0.99      1.00      0.99        75
#     Normal_1       0.94      0.97      0.95        75
#   OR_007_6_1       1.00      1.00      1.00        75
#   OR_014_6_1       0.77      0.91      0.83        75
#   OR_021_6_1       0.97      0.99      0.98        75
#
#     accuracy                           0.94       750
#    macro avg       0.94      0.94      0.94       750
# weighted avg       0.94      0.94      0.94       750

# %%
parameters = {"C":[1, 10, 45, 47,49, 50, 51, 55, 100, 300, 500],
             'gamma':[0.01, 0.05, 0.1, 0.5, 1, 5],
             'kernel':["rbf"]}

# %%
# Define the Grid Search optimization analysis
tuned_svm_clf = GridSearchCV(SVC(),parameters,n_jobs = -1, cv= 10)
tuned_svm_clf
# Out:
# GridSearchCV(cv=10, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [1, 10, 45, 47, 49, 50, 51, 55, 100, 300, 500],
#                          'gamma': [0.01, 0.05, 0.1, 0.5, 1, 5],
#                          'kernel': ['rbf']})

# %%
# Train the move for the every pair of hyperparameters,
#   and determine the best combination
tuned_svm_clf.fit(train_data_scaled, train_data['fault'])
# Out:
# GridSearchCV(cv=10, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [1, 10, 45, 47, 49, 50, 51, 55, 100, 300, 500],
#                          'gamma': [0.01, 0.05, 0.1, 0.5, 1, 5],
#                          'kernel': ['rbf']})

# %%
# Hyperparameter of the best model
tuned_svm_clf.best_params_
# Out:
# {'C': 55, 'gamma': 0.05, 'kernel': 'rbf'}

# %%
#Let's select the best model and provide results on them
best_clf = tuned_svm_clf.best_estimator_
best_clf
# Out:
# SVC(C=55, gamma=0.05)

# %%
# Compute the predictions
train_predictions_best = best_clf.predict(train_data_scaled)
test_predictions_best = best_clf.predict(test_data_scaled)

# %%
# Compute confusion matrix for training and test datasets
train_confu_matrix_best = confusion_matrix(train_data['fault'], train_predictions_best)
test_confu_matrix_best = confusion_matrix(test_data['fault'], test_predictions_best)

# %%
plt.figure(1,figsize=(18,8))

plt.subplot(121)
sns.heatmap(train_confu_matrix_best, annot= True,fmt = "d",
xticklabels=fault_type, yticklabels=fault_type, cmap = "Blues", cbar = False)
plt.title('Training Confusion Matrix (best model)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.subplot(122)

plt.subplot(122)
sns.heatmap(test_confu_matrix_best, annot = True,
xticklabels=fault_type, yticklabels=fault_type, cmap = "Blues", cbar = False)
plt.title('Test Confusion Matrix (best model)')
plt.xlabel('Predicted')
plt.ylabel('True')

plt.show()

# %%
# Classification report (test set)
class_report_best = classification_report(y_pred = test_predictions_best, y_true = test_data['fault'])
print(class_report_best)
# Out:
#               precision    recall  f1-score   support
#
#   Ball_007_1       0.95      0.99      0.97        75
#   Ball_014_1       0.94      0.88      0.91        75
#   Ball_021_1       0.97      0.89      0.93        75
#     IR_007_1       0.99      1.00      0.99        75
#     IR_014_1       1.00      1.00      1.00        75
#     IR_021_1       1.00      1.00      1.00        75
#     Normal_1       0.97      1.00      0.99        75
#   OR_007_6_1       1.00      1.00      1.00        75
#   OR_014_6_1       0.84      0.89      0.86        75
#   OR_021_6_1       0.99      0.99      0.99        75
#
#     accuracy                           0.96       750
#    macro avg       0.96      0.96      0.96       750
# weighted avg       0.96      0.96      0.96       750

# %%
# Remember the metrics for the non-optimized model
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#   Ball_007_1       0.92      0.97      0.95        75
#   Ball_014_1       0.86      0.72      0.78        75
#   Ball_021_1       0.95      0.81      0.88        75
#     IR_007_1       0.99      1.00      0.99        75
#     IR_014_1       1.00      1.00      1.00        75
#     IR_021_1       0.99      1.00      0.99        75
#     Normal_1       0.94      0.97      0.95        75
#   OR_007_6_1       1.00      1.00      1.00        75
#   OR_014_6_1       0.77      0.91      0.83        75
#   OR_021_6_1       0.97      0.99      0.98        75
#
#     accuracy                           0.94       750
#    macro avg       0.94      0.94      0.94       750
# weighted avg       0.94      0.94      0.94       750

# %%
# Logistic regression classifier
from sklearn.linear_model import LogisticRegression

# Setup the model
logis_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Train the model
logis_model.fit(train_data_scaled, train_data['fault'])
# Out:
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
# Compute the predictions
test_predictions_lr = logis_model.predict(test_data_scaled)

# %%
# Compute confusion matrix 
test_confu_matrix_lr = confusion_matrix(test_data['fault'], test_predictions_lr)

# %%
# Classification report
class_report_lr = classification_report(y_pred = test_predictions_lr, y_true = test_data['fault'])
print(class_report_lr)
# Out:
#               precision    recall  f1-score   support
#
#   Ball_007_1       0.91      1.00      0.96        75
#   Ball_014_1       0.83      0.77      0.80        75
#   Ball_021_1       0.92      0.88      0.90        75
#     IR_007_1       0.99      1.00      0.99        75
#     IR_014_1       1.00      1.00      1.00        75
#     IR_021_1       0.99      1.00      0.99        75
#     Normal_1       0.94      0.97      0.95        75
#   OR_007_6_1       1.00      1.00      1.00        75
#   OR_014_6_1       0.86      0.81      0.84        75
#   OR_021_6_1       0.99      0.99      0.99        75
#
#     accuracy                           0.94       750
#    macro avg       0.94      0.94      0.94       750
# weighted avg       0.94      0.94      0.94       750

# %%
# Compute the predictions
train_predictions_logis = logis_model.predict(train_data_scaled)
test_predictions_logis = logis_model.predict(test_data_scaled)

# %%
# Classification report (test set)
class_report_logis = classification_report(y_pred = test_predictions_logis, y_true = test_data['fault'])
print(class_report_logis)
# Out:
#               precision    recall  f1-score   support
#
#   Ball_007_1       0.91      1.00      0.96        75
#   Ball_014_1       0.83      0.77      0.80        75
#   Ball_021_1       0.92      0.88      0.90        75
#     IR_007_1       0.99      1.00      0.99        75
#     IR_014_1       1.00      1.00      1.00        75
#     IR_021_1       0.99      1.00      0.99        75
#     Normal_1       0.94      0.97      0.95        75
#   OR_007_6_1       1.00      1.00      1.00        75
#   OR_014_6_1       0.86      0.81      0.84        75
#   OR_021_6_1       0.99      0.99      0.99        75
#
#     accuracy                           0.94       750
#    macro avg       0.94      0.94      0.94       750
# weighted avg       0.94      0.94      0.94       750

# %%
plt.figure(1,figsize=(8,6))

sns.heatmap(test_confu_matrix_lr, annot = True,
xticklabels=fault_type, yticklabels=fault_type, cmap = "Blues", cbar = False)
plt.title('Test Confusion Matrix (logistic regression)')
plt.xlabel('Predicted')
plt.ylabel('True')

plt.show()

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# 读取数据
data = pd.read_csv('archive/feature_time_48k_2048_load_1.csv')

# 特征选择
features = ['max', 'min', 'mean', 'sd', 'rms', 'skewness', 'kurtosis', 'crest', 'form']
target = 'fault'
normal_class = 'Normal_1'

# 数据预处理
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data[features])

# 定义稀疏去噪自编码器网络
class Autoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Sigmoid()
        )
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, input_dim),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# 训练稀疏去噪自编码器模型
input_dim = len(features)
hidden_dim = 10
autoencoder = Autoencoder(input_dim, hidden_dim)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(autoencoder.parameters(), lr=0.001)

num_epochs = 200
batch_size = 32

data_tensor = torch.tensor(data_scaled, dtype=torch.float32)
data_loader = torch.utils.data.DataLoader(data_tensor, batch_size=batch_size, shuffle=True)

for epoch in range(num_epochs):
    total_loss = 0
    for data_batch in data_loader:
        optimizer.zero_grad()
        _, recon_batch = autoencoder(data_batch)
        loss = criterion(recon_batch, data_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(data_loader)
    print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}')

# 提取编码器特征
encoded_data, _ = autoencoder(data_tensor)
encoded_data_np = encoded_data.detach().numpy()

# 训练孤立森林模型进行异常检测
fault_labels = np.where(data[target] == normal_class, 0, 1)
clf = IsolationForest(contamination=0.001)
clf.fit(encoded_data_np)

# 预测异常样本
pred_labels = clf.predict(encoded_data_np)
anomaly_scores = clf.decision_function(encoded_data_np)

# 统计异常检测结果
accuracy = np.mean(pred_labels == fault_labels)
print(f'异常检测准确率: {accuracy:.2%}')
# Out:
# Epoch [1/200], Average Loss: 0.1242
# Epoch [2/200], Average Loss: 0.0814
# Epoch [3/200], Average Loss: 0.0562
# Epoch [4/200], Average Loss: 0.0438
# Epoch [5/200], Average Loss: 0.0376
# Epoch [6/200], Average Loss: 0.0337
# Epoch [7/200], Average Loss: 0.0307
# Epoch [8/200], Average Loss: 0.0281
# Epoch [9/200], Average Loss: 0.0258
# Epoch [10/200], Average Loss: 0.0238
# Epoch [11/200], Average Loss: 0.0219
# Epoch [12/200], Average Loss: 0.0203
# Epoch [13/200], Average Loss: 0.0187
# Epoch [14/200], Average Loss: 0.0173
# Epoch [15/200], Average Loss: 0.0161
# Epoch [16/200], Average Loss: 0.0150
# Epoch [17/200], Average Loss: 0.0140
# Epoch [18/200], Average Loss: 0.0132
# Epoch [19/200], Average Loss: 0.0125
# Epoch [20/200], Average Loss: 0.0119
# Epoch [21/200], Average Loss: 0.0114
# Epoch [22/200], Average Loss: 0.0110
# Epoch [23/200], Average Loss: 0.0106
# Epoch [24/200], Average Loss: 0.0103
# Epoch [25/200], Average Loss: 0.0101
# Epoch [26/200], Average Loss: 0.0098
# Epoch [27/200], Average Loss: 0.0096
# Epoch [28/200], Average Loss: 0.0094
# Epoch [29/200], Average Loss: 0.0092
# Epoch [30/200], Average Loss: 0.0090
# Epoch [31/200], Average Loss: 0.0088
# Epoch [32/200], Average Loss: 0.0085
# Epoch [33/200], Average Loss: 0.0083
# Epoch [34/200], Average Loss: 0.0080
# Epoch [35/200], Average Loss: 0.0078
# Epoch [36/200], Average Loss: 0.0075
# Epoch [37/200], Average Loss: 0.0072
# Epoch [38/200], Average Loss: 0.0069
# Epoch [39/200], Average Loss: 0.0067
# Epoch [40/200], Average Loss: 0.0064
# Epoch [41/200], Average Loss: 0.0061
# Epoch [42/200], Average Loss: 0.0058
# Epoch [43/200], Average Loss: 0.0055
# Epoch [44/200], Average Loss: 0.0053
# Epoch [45/200], Average Loss: 0.0050
# Epoch [46/200], Average Loss: 0.0048
# Epoch [47/200], Average Loss: 0.0045
# Epoch [48/200], Average Loss: 0.0043
# Epoch [49/200], Average Loss: 0.0041
# Epoch [50/200], Average Loss: 0.0039
# Epoch [51/200], Average Loss: 0.0037
# Epoch [52/200], Average Loss: 0.0035
# Epoch [53/200], Average Loss: 0.0033
# Epoch [54/200], Average Loss: 0.0031
# Epoch [55/200], Average Loss: 0.0030
# Epoch [56/200], Average Loss: 0.0029
# Epoch [57/200], Average Loss: 0.0027
# Epoch [58/200], Average Loss: 0.0026
# Epoch [59/200], Average Loss: 0.0025
# Epoch [60/200], Average Loss: 0.0024
# Epoch [61/200], Average Loss: 0.0023
# Epoch [62/200], Average Loss: 0.0023
# Epoch [63/200], Average Loss: 0.0022
# Epoch [64/200], Average Loss: 0.0021
# Epoch [65/200], Average Loss: 0.0020
# Epoch [66/200], Average Loss: 0.0020
# Epoch [67/200], Average Loss: 0.0019
# Epoch [68/200], Average Loss: 0.0019
# Epoch [69/200], Average Loss: 0.0018
# Epoch [70/200], Average Loss: 0.0018
# Epoch [71/200], Average Loss: 0.0017
# Epoch [72/200], Average Loss: 0.0017
# Epoch [73/200], Average Loss: 0.0017
# Epoch [74/200], Average Loss: 0.0016
# Epoch [75/200], Average Loss: 0.0016
# Epoch [76/200], Average Loss: 0.0016
# Epoch [77/200], Average Loss: 0.0015
# Epoch [78/200], Average Loss: 0.0015
# Epoch [79/200], Average Loss: 0.0015
# Epoch [80/200], Average Loss: 0.0015
# Epoch [81/200], Average Loss: 0.0014
# Epoch [82/200], Average Loss: 0.0014
# Epoch [83/200], Average Loss: 0.0014
# Epoch [84/200], Average Loss: 0.0014
# Epoch [85/200], Average Loss: 0.0013
# Epoch [86/200], Average Loss: 0.0013
# Epoch [87/200], Average Loss: 0.0013
# Epoch [88/200], Average Loss: 0.0013
# Epoch [89/200], Average Loss: 0.0013
# Epoch [90/200], Average Loss: 0.0013
# Epoch [91/200], Average Loss: 0.0012
# Epoch [92/200], Average Loss: 0.0012
# Epoch [93/200], Average Loss: 0.0012
# Epoch [94/200], Average Loss: 0.0012
# Epoch [95/200], Average Loss: 0.0012
# Epoch [96/200], Average Loss: 0.0012
# Epoch [97/200], Average Loss: 0.0011
# Epoch [98/200], Average Loss: 0.0011
# Epoch [99/200], Average Loss: 0.0011
# Epoch [100/200], Average Loss: 0.0011
# Epoch [101/200], Average Loss: 0.0011
# Epoch [102/200], Average Loss: 0.0011
# Epoch [103/200], Average Loss: 0.0011
# Epoch [104/200], Average Loss: 0.0010
# Epoch [105/200], Average Loss: 0.0010
# Epoch [106/200], Average Loss: 0.0010
# Epoch [107/200], Average Loss: 0.0010
# Epoch [108/200], Average Loss: 0.0010
# Epoch [109/200], Average Loss: 0.0010
# Epoch [110/200], Average Loss: 0.0009
# Epoch [111/200], Average Loss: 0.0009
# Epoch [112/200], Average Loss: 0.0009
# Epoch [113/200], Average Loss: 0.0009
# Epoch [114/200], Average Loss: 0.0009
# Epoch [115/200], Average Loss: 0.0009
# Epoch [116/200], Average Loss: 0.0008
# Epoch [117/200], Average Loss: 0.0008
# Epoch [118/200], Average Loss: 0.0008
# Epoch [119/200], Average Loss: 0.0008
# Epoch [120/200], Average Loss: 0.0008
# Epoch [121/200], Average Loss: 0.0008
# Epoch [122/200], Average Loss: 0.0007
# Epoch [123/200], Average Loss: 0.0007
# Epoch [124/200], Average Loss: 0.0007
# Epoch [125/200], Average Loss: 0.0007
# Epoch [126/200], Average Loss: 0.0007
# Epoch [127/200], Average Loss: 0.0007
# Epoch [128/200], Average Loss: 0.0006
# Epoch [129/200], Average Loss: 0.0006
# Epoch [130/200], Average Loss: 0.0006
# Epoch [131/200], Average Loss: 0.0006
# Epoch [132/200], Average Loss: 0.0006
# Epoch [133/200], Average Loss: 0.0006
# Epoch [134/200], Average Loss: 0.0006
# Epoch [135/200], Average Loss: 0.0005
# Epoch [136/200], Average Loss: 0.0005
# Epoch [137/200], Average Loss: 0.0005
# Epoch [138/200], Average Loss: 0.0005
# Epoch [139/200], Average Loss: 0.0005
# Epoch [140/200], Average Loss: 0.0005
# Epoch [141/200], Average Loss: 0.0005
# Epoch [142/200], Average Loss: 0.0005
# Epoch [143/200], Average Loss: 0.0005
# Epoch [144/200], Average Loss: 0.0005
# Epoch [145/200], Average Loss: 0.0005
# Epoch [146/200], Average Loss: 0.0004
# Epoch [147/200], Average Loss: 0.0004
# Epoch [148/200], Average Loss: 0.0004
# Epoch [149/200], Average Loss: 0.0004
# Epoch [150/200], Average Loss: 0.0004
# Epoch [151/200], Average Loss: 0.0004
# Epoch [152/200], Average Loss: 0.0004
# Epoch [153/200], Average Loss: 0.0004
# Epoch [154/200], Average Loss: 0.0004
# Epoch [155/200], Average Loss: 0.0004
# Epoch [156/200], Average Loss: 0.0004
# Epoch [157/200], Average Loss: 0.0004
# Epoch [158/200], Average Loss: 0.0004
# Epoch [159/200], Average Loss: 0.0004
# Epoch [160/200], Average Loss: 0.0004
# Epoch [161/200], Average Loss: 0.0004
# Epoch [162/200], Average Loss: 0.0004
# Epoch [163/200], Average Loss: 0.0004
# Epoch [164/200], Average Loss: 0.0004
# Epoch [165/200], Average Loss: 0.0004
# Epoch [166/200], Average Loss: 0.0004
# Epoch [167/200], Average Loss: 0.0004
# Epoch [168/200], Average Loss: 0.0004
# Epoch [169/200], Average Loss: 0.0004
# Epoch [170/200], Average Loss: 0.0004
# Epoch [171/200], Average Loss: 0.0003
# Epoch [172/200], Average Loss: 0.0003
# Epoch [173/200], Average Loss: 0.0003
# Epoch [174/200], Average Loss: 0.0003
# Epoch [175/200], Average Loss: 0.0003
# Epoch [176/200], Average Loss: 0.0003
# Epoch [177/200], Average Loss: 0.0003
# Epoch [178/200], Average Loss: 0.0003
# Epoch [179/200], Average Loss: 0.0003
# Epoch [180/200], Average Loss: 0.0003
# Epoch [181/200], Average Loss: 0.0003
# Epoch [182/200], Average Loss: 0.0003
# Epoch [183/200], Average Loss: 0.0003
# Epoch [184/200], Average Loss: 0.0003
# Epoch [185/200], Average Loss: 0.0003
# Epoch [186/200], Average Loss: 0.0003
# Epoch [187/200], Average Loss: 0.0003
# Epoch [188/200], Average Loss: 0.0003
# Epoch [189/200], Average Loss: 0.0003
# Epoch [190/200], Average Loss: 0.0003
# Epoch [191/200], Average Loss: 0.0003
# Epoch [192/200], Average Loss: 0.0003
# Epoch [193/200], Average Loss: 0.0003
# Epoch [194/200], Average Loss: 0.0003
# Epoch [195/200], Average Loss: 0.0003
# Epoch [196/200], Average Loss: 0.0003
# Epoch [197/200], Average Loss: 0.0003
# Epoch [198/200], Average Loss: 0.0003
# Epoch [199/200], Average Loss: 0.0003
# Epoch [200/200], Average Loss: 0.0003
# 异常检测准确率: 89.87%

# %%
# 计算准确率、召回率和F1分数
accuracy = accuracy_score(val_y, test_y_pred_final)
print(val_y)
recall = recall_score(val_y, test_y_pred_final, average='macro')  # 设置average为'macro'
f1 = f1_score(val_y, test_y_pred_final, average='macro')  # 设置average为'macro'

print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('Recall: {:.2f}%'.format(recall * 100))
print('F1 Score: {:.2f}'.format(f1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # 计算准确率、召回率和F1分数
# ----> 2 accuracy = accuracy_score(val_y, test_y_pred_final)
#       3 print(val_y)
#       4 recall = recall_score(val_y, test_y_pred_final, average='macro')  # 设置average为'macro'
#
# NameError: name 'val_y' is not defined
